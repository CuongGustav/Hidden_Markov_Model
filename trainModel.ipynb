# %%
import os
import shutil
 
# Thư mục chứa các folder A, B, ..., T
source_dir = "train"
# Thư mục đích để lưu dữ liệu tổ chức lại
destination_dir = "datasets"
 
# Danh sách tên thư mục mới thay vì 01, 02, ..., 52
folder_names = [
    'A', 'Ba', 'Bài', 'Bảy', 'Bốn', 'Chậm', 'Chạy', 'Chín', 'Chủ', 'Có',
    'Cuối', 'Đầu', 'Đọc', 'Dừng', 'Đúng', 'E', 'Giảm', 'Giờ', 'Giúp', 'Hai',
    'Hủy', 'I', 'Kế', 'Không', 'Lại', 'Lặp', 'Lui', 'Lưu', 'Một', 'Mục',
    'Năm', 'Ngày', 'Ngừng', 'Nhanh', 'Nhỏ', 'O', 'Sai', 'Sáu', 'Tải', 'Tám',
    'Tăng', 'Thổ địa', 'Tiếp', 'To', 'Tới', 'Trước', 'Tuổi', 'U', 'Vào', 'Về',
    'Xóa', 'Xong'
]
# Tạo thư mục đích theo tên trong danh sách
for name in folder_names:
    os.makedirs(os.path.join(destination_dir, name), exist_ok=True)
 
# Duyệt qua các folder A, B, ..., T
for folder in sorted(os.listdir(source_dir)):
    folder_path = os.path.join(source_dir, folder)
    if os.path.isdir(folder_path):
        # Duyệt qua từng file trong folder
        for file in sorted(os.listdir(folder_path)):
            # Xác định số thứ tự của file (e.g., 'B01.wav' -> '01')
            file_index = int(file[1:3]) - 1  # Để phù hợp với index trong folder_names
            # Thư mục đích tương ứng
            target_folder = os.path.join(destination_dir, folder_names[file_index])
            # Đường dẫn nguồn và đích của file
            source_file = os.path.join(folder_path, file)
            destination_file = os.path.join(target_folder, file)
            # Di chuyển file
            shutil.move(source_file, destination_file)
            print(f"Moved {source_file} to {destination_file}")

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from hmmlearn.hmm import GMMHMM
import preprocessing
import seaborn as sns
from sklearn.model_selection import KFold


class HMMTraining:
    def __init__(self, n_mixtures=3, n_states=5, n_features=12):
        self.class_names = [
                            'A', 'Ba', 'Bài', 'Bảy', 'Bốn', 'Chậm', 'Chạy', 'Chín', 'Chủ', 'Có',
                            'Cuối', 'Đầu', 'Đọc', 'Dừng', 'Đúng', 'E', 'Giảm', 'Giờ', 'Giúp', 'Hai',
                            'Hủy', 'I', 'Kế', 'Không', 'Lại', 'Lặp', 'Lui', 'Lưu', 'Một', 'Mục',
                            'Năm', 'Ngày', 'Ngừng', 'Nhanh', 'Nhỏ', 'O', 'Sai', 'Sáu', 'Tải', 'Tám',
                            'Tăng', 'Thổ địa', 'Tiếp', 'To', 'Tới', 'Trước', 'Tuổi', 'U', 'Vào', 'Về',
                            'Xóa', 'Xong'"
                            ]
        
        self.n_states = n_states
        self.n_mixtures = n_mixtures
        self.dataset_path = './datasets'  # Đường dẫn bộ dữ liệu
        self.n_features = n_features

        self.X = {'train': {}, 'test': {}}
        self.y = {'train': {}, 'test': {}}

        self.models = {}
        self.loss_history = {}
        self.model_path = './models_train'  # Thư mục lưu mô hình

    def preprocess_data(self):
        for cname in self.class_names:
            folder_path = os.path.join(self.dataset_path, cname)
            file_paths = [
                os.path.join(folder_path, file_name)
                for file_name in os.listdir(folder_path)
                if file_name.endswith('.wav')
            ]

            # Xử lý MFCC từ mỗi file
            data = [
                mfcc for file_path in file_paths
                if (mfcc := preprocessing.get_mfcc(file_path, self.n_features)) is not None
            ]
            labels = [self.class_names.index(cname)] * len(data)

            if len(data) == 0:
                print(f"Warning: No valid MFCC data for class {cname}")
                continue

            # Chia dữ liệu thành tập train và test
            x_train, x_test, y_train, y_test = train_test_split(
                data, labels, test_size=0.2, random_state=42
            )

            self.X['train'][cname] = x_train
            self.X['test'][cname] = x_test
            self.y['test'][cname] = y_test

    def train(self):
        self.preprocess_data()

        for cname in self.class_names:
            if cname not in self.X['train'] or len(self.X['train'][cname]) == 0:
                print(f"Skipping training for class {cname}: No training data.")
                continue

            train_data = np.vstack(self.X['train'][cname])
            lengths = [x.shape[0] for x in self.X['train'][cname]]

            model = GMMHMM(
                n_components=self.n_states,
                n_mix=self.n_mixtures,
                covariance_type='diag',
                n_iter=300,
                random_state=42
            )
            model.fit(train_data, lengths)
            self.models[cname] = model

            self.loss_history[cname] = model.monitor_.history

        os.makedirs(self.model_path, exist_ok=True)
        for cname, model in self.models.items():
            model_file = os.path.join(self.model_path, f'model_{cname}_hmm.pkl')
            with open(model_file, 'wb') as f:
                pickle.dump(model, f)

    def predict(self, audio_path):
        # Trích xuất đặc trưng MFCC từ tệp âm thanh
        mfcc = preprocessing.get_mfcc(audio_path, self.n_features)

        if mfcc is None:
            print(f"Không thể trích xuất đặc trưng từ âm thanh: {audio_path}")
            return None

        # Tính toán điểm số cho từng mô hình
        scores = {}
        for cname, model in self.models.items():
            score = model.score(mfcc)  # Tính điểm số cho mô hình của lớp cname
            scores[cname] = score

        # Chọn lớp có điểm số cao nhất
        predicted_class = max(scores, key=scores.get)
        predicted_score = scores[predicted_class]

        print(f"Dự đoán lớp: {predicted_class}, Điểm số: {predicted_score}")
        return predicted_class, predicted_score

    def evaluation(self):
        y_true = []
        y_pred = []

        for cname in self.class_names:
            if cname not in self.X['test']:
                print(f"Skipping evaluation for class {cname}: No test data.")
                continue

            for mfcc, label in zip(self.X['test'][cname], self.y['test'][cname]):
                scores = [model.score(mfcc) for model in self.models.values()]
                pred = np.argmax(scores)
                y_pred.append(pred)
                y_true.append(label)

        acc = accuracy_score(y_true, y_pred)
        cm = confusion_matrix(y_true, y_pred)

        cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

        class_accuracy = {}
        for i, cname in enumerate(self.class_names):
            class_accuracy[cname] = cm[i, i] / cm[i].sum() if cm[i].sum() > 0 else 0.0

        return acc, cm, cm_percent, class_accuracy

    def load_models(self):
        model_files = [f for f in os.listdir(self.model_path) if f.endswith('.pkl')]
        
        for model_file in model_files:
            model_path = os.path.join(self.model_path, model_file)
            # Lấy tên lớp từ tên file, bỏ tiền tố 'model_' và hậu tố '_hmm'
            model_name = model_file.replace('model_', '').replace('_hmm.pkl', '')
            try:
                with open(model_path, 'rb') as f:
                    model = pickle.load(f)
                self.models[model_name] = model
                print(f"Tải thành công mô hình: {model_name}")
            except Exception as e:
                print(f"Lỗi khi tải mô hình {model_name}: {e}")


    def plot_loss(self):
        fig, axs = plt.subplots(len(self.loss_history), 1, figsize=(9, len(self.loss_history) * 6))

        for i, (cname, history) in enumerate(self.loss_history.items()):
            axs[i].plot(history, label=f'Log-likelihood ({cname})', color='blue')
            axs[i].set_title(f'Log-likelihood During Training - Class: {cname}')
            axs[i].set_xlabel('Epochs')
            axs[i].set_ylabel('Log-likelihood')
            axs[i].legend()
            axs[i].grid(True)

        plt.tight_layout()
        plt.show()

    def plot_confusion_matrix(self, cm):
        """
        Vẽ ma trận nhầm lẫn hiển thị số lượng đúng/sai.
        
        Args:
            cm (numpy.ndarray): Ma trận nhầm lẫn.
        """
        plt.figure(figsize=(30, 15))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title('Confusion Matrix (Counts)')
        plt.colorbar()
        tick_marks = np.arange(len(self.class_names))
        plt.xticks(tick_marks, self.class_names, rotation=45)
        plt.yticks(tick_marks, self.class_names)

        # Ngưỡng để thay đổi màu chữ dựa trên nền
        thresh = cm.max() / 2
        for i, j in np.ndindex(cm.shape):
            plt.text(j, i, f"{cm[i, j]}",
                    horizontalalignment="center",
                    color="white" if cm[i, j] > thresh else "black")

        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.tight_layout()
        plt.show()
    def predict_dataset(self, dataset_path):
        y_true = []
        y_pred = []

        for folder_name in os.listdir(dataset_path):
            folder_path = os.path.join(dataset_path, folder_name)
            if not os.path.isdir(folder_path) or folder_name not in self.class_names:
                print(f"Bỏ qua: {folder_name} (không phải folder hợp lệ hoặc không nằm trong class_names)")
                continue

            true_label = folder_name  # Tên folder là nhãn thực tế
            file_paths = [
                os.path.join(folder_path, file_name)
                for file_name in os.listdir(folder_path)
                if file_name.endswith('.wav')
            ]

            if not file_paths:
                print(f"Folder {folder_name} không chứa file .wav nào.")
                continue

            for file_path in file_paths:
                # Dự đoán lớp
                predicted_class, _ = self.predict(file_path)

                # Đảm bảo chỉ lưu nhãn lớp (không có tiền tố/hậu tố)
                if predicted_class in self.class_names:
                    y_pred.append(predicted_class)
                    y_true.append(true_label)
                else:
                    print(f"Lỗi: {predicted_class} không có trong danh sách class_names.")

        # Chuyển nhãn thành chỉ số để tính ma trận nhầm lẫn
        y_true_indices = [self.class_names.index(label) for label in y_true]
        y_pred_indices = [self.class_names.index(label) for label in y_pred]

        # Tính ma trận nhầm lẫn và độ chính xác
        cm = confusion_matrix(y_true_indices, y_pred_indices)
        acc = accuracy_score(y_true_indices, y_pred_indices)

        # Hiển thị kết quả
        print(f"Accuracy trên tập dữ liệu test: {acc * 100:.2f}%")
        self.plot_confusion_matrix(cm)
    def preprocess_data_all(self):
            for cname in self.class_names:
                folder_path = os.path.join(self.dataset_path, cname)
                file_paths = [
                    os.path.join(folder_path, file_name)
                    for file_name in os.listdir(folder_path)
                    if file_name.endswith('.wav')
                ]

                # Xử lý MFCC từ mỗi file
                data = [
                    mfcc for file_path in file_paths
                    if (mfcc := preprocessing.get_mfcc(file_path, self.n_features)) is not None
                ]

                if len(data) == 0:
                    print(f"Warning: No valid MFCC data for class {cname}")
                    continue

                # Lưu toàn bộ dữ liệu vào self.X và self.y
                self.X[cname] = data
                self.y[cname] = [self.class_names.index(cname)] * len(data)

    def train_all(self):
        self.preprocess_data_all()

        for cname in self.class_names:
            if cname not in self.X or len(self.X[cname]) == 0:
                print(f"Skipping training for class {cname}: No training data.")
                continue

            train_data = np.vstack(self.X[cname])
            lengths = [x.shape[0] for x in self.X[cname]]

            model = GMMHMM(
                n_components=self.n_states,
                n_mix=self.n_mixtures,
                covariance_type='diag',
                n_iter=300,
                random_state=42
            )
            model.fit(train_data, lengths)
            self.models[cname] = model

            self.loss_history[cname] = model.monitor_.history

        os.makedirs(self.model_path, exist_ok=True)
        for cname, model in self.models.items():
            model_file = os.path.join(self.model_path, f'model_{cname}_hmm.pkl')
            with open(model_file, 'wb') as f:
                pickle.dump(model, f)

# %%
if __name__ == '__main__':
    # Thiết lập thông số HMM
    n_states = 3
    n_mixtures = 3
    n_features = 12

    # Khởi tạo và huấn luyện HMM
    hmm_train = HMMTraining(n_mixtures=n_mixtures, n_states=n_states, n_features=n_features)
    hmm_train.train()

    # Đánh giá mô hình
    acc, cm, cm_percent, class_accuracy = hmm_train.evaluation()

    # Hiển thị kết quả
    print(f"Độ chính xác tổng thể: {acc * 100:.2f}%")
    print("Độ chính xác từng lớp:")
    for class_name, class_acc in class_accuracy.items():
        print(f"- {class_name}: {class_acc * 100:.2f}%")
    
    # Vẽ ma trận nhầm lẫn
    hmm_train.plot_confusion_matrix(cm)
# Out:
# Độ chính xác tổng thể: 79.33%
# Độ chính xác từng lớp:
# - chủ: 100.00%
# - Về: 100.00%
# - Vào: 75.00%
# - Tải: 50.00%
# - Đầu: 100.00%
# - Cuối: 100.00%
# - Kế: 100.00%
# - Trước: 100.00%
# - Dừng: 75.00%
# - Ngừng: 100.00%
# - Đọc: 100.00%
# - Tiếp: 100.00%
# - Lui: 75.00%
# - Tới: 75.00%
# - Tăng: 75.00%
# - To: 75.00%
# - Giảm: 75.00%
# - Nhỏ: 75.00%
# - Lại: 75.00%
# - Lặp: 100.00%
# - Nhanh: 75.00%
# - Chậm: 75.00%
# - Lưu: 75.00%
# - Xóa: 75.00%
# - Hủy: 75.00%
# - Chạy: 75.00%
# - Xong: 100.00%
# - Đúng: 75.00%
# - Sai: 50.00%
# - Giúp: 100.00%
# - Giờ: 100.00%
# - Ngày: 75.00%
# - Tươi: 50.00%
# - Có: 75.00%
# - Không: 75.00%
# - Mục: 75.00%
# - Bài: 75.00%
# - Một: 75.00%
# - Hai: 75.00%
# - Ba: 75.00%
# - Bốn: 75.00%
# - Năm: 100.00%
# - Sáu: 75.00%
# - Bảy: 75.00%
# - Tám: 75.00%
# - Chín: 75.00%
# - A: 50.00%
# - E: 50.00%
# - I: 75.00%
# - O: 50.00%
# - U: 100.00%
# - Thổ địa: 75.00%

# %%
if __name__ == '__main__':   
    results = []  
    for n_features in range(11, 14):
        print('n_features = ', n_features)
        print(f"{'nStates':<8}", end="")
        for i in [3, 5, 7]: 
            print(f"{i:<8}", end="")
        print('\nn_mix')
        print( "="*58)
        
        for n_mixtures in range(2, 5):  
            row = [str(n_mixtures)]  
            for n_states in [3, 5, 7]: 
                hmm_train = HMMTraining(n_mixtures=n_mixtures, n_states=n_states, n_features=n_features)
                hmm_train.train()
                accuracy, cm, cm_percent, class_accuracy = hmm_train.evaluation()
                row.append(f"{accuracy*100:.2f}%")

            print(f"{row[0]:<8}{row[1]:<8}{row[2]:<8}{row[3]:<8}")
# Out:
# n_features =  11
# nStates 3       5       7
# n_mix
# ==========================================================
# 2       73.08%  78.37%  76.92%
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# 3       75.00%  79.33%  78.85%
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# 4       78.37%  77.88%  81.73%
# n_features =  12
# nStates 3       5       7
# n_mix
# ==========================================================
# 2       74.04%  78.85%  79.33%
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# ...
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# Degenerate mixture covariance
# 4       77.88%  83.17%  84.13%

# %%
if __name__ == '__main__':
    # Thiết lập thông số HMM
    n_states = 7
    n_mixtures = 3
    n_features = 13

    # Khởi tạo và huấn luyện HMM
    hmm_train = HMMTraining(n_mixtures=n_mixtures, n_states=n_states, n_features=n_features)
    hmm_train.train()

    # Đánh giá mô hình
    acc, cm, cm_percent, class_accuracy = hmm_train.evaluation()

    # Hiển thị kết quả
    print(f"Độ chính xác tổng thể: {acc * 100:.2f}%")
    print("Độ chính xác từng lớp:")
    for class_name, class_acc in class_accuracy.items():
        print(f"- {class_name}: {class_acc * 100:.2f}%")
    
    # Vẽ ma trận nhầm lẫn
    hmm_train.plot_confusion_matrix(cm)
    hmm_train.plot_loss()
# Out:
# Độ chính xác tổng thể: 84.13%
# Độ chính xác từng lớp:
# - chủ: 100.00%
# - Về: 100.00%
# - Vào: 75.00%
# - Tải: 75.00%
# - Đầu: 100.00%
# - Cuối: 100.00%
# - Kế: 100.00%
# - Trước: 75.00%
# - Dừng: 75.00%
# - Ngừng: 100.00%
# - Đọc: 100.00%
# - Tiếp: 100.00%
# - Lui: 100.00%
# - Tới: 100.00%
# - Tăng: 75.00%
# - To: 75.00%
# - Giảm: 75.00%
# - Nhỏ: 75.00%
# - Lại: 50.00%
# - Lặp: 100.00%
# - Nhanh: 75.00%
# - Chậm: 75.00%
# - Lưu: 75.00%
# - Xóa: 100.00%
# - Hủy: 75.00%
# - Chạy: 75.00%
# - Xong: 100.00%
# - Đúng: 100.00%
# - Sai: 75.00%
# - Giúp: 100.00%
# - Giờ: 100.00%
# - Ngày: 75.00%
# - Tươi: 75.00%
# - Có: 50.00%
# - Không: 75.00%
# - Mục: 100.00%
# - Bài: 75.00%
# - Một: 100.00%
# - Hai: 75.00%
# - Ba: 75.00%
# - Bốn: 75.00%
# - Năm: 100.00%
# - Sáu: 100.00%
# - Bảy: 100.00%
# - Tám: 75.00%
# - Chín: 75.00%
# - A: 50.00%
# - E: 50.00%
# - I: 75.00%
# - O: 75.00%
# - U: 100.00%
# - Thổ địa: 100.00%

# %%
import os
import shutil
 
source_dir = "test"
destination_dir = "datasettest"
 
folder_names = [
    'A', 'Ba', 'Bài', 'Bảy', 'Bốn', 'Chậm', 'Chạy', 'Chín', 'Chủ', 'Có',
    'Cuối', 'Đầu', 'Đọc', 'Dừng', 'Đúng', 'E', 'Giảm', 'Giờ', 'Giúp', 'Hai',
    'Hủy', 'I', 'Kế', 'Không', 'Lại', 'Lặp', 'Lui', 'Lưu', 'Một', 'Mục',
    'Năm', 'Ngày', 'Ngừng', 'Nhanh', 'Nhỏ', 'O', 'Sai', 'Sáu', 'Tải', 'Tám',
    'Tăng', 'Thổ địa', 'Tiếp', 'To', 'Tới', 'Trước', 'Tuổi', 'U', 'Vào', 'Về',
    'Xóa', 'Xong'
]
 
for name in folder_names:
    os.makedirs(os.path.join(destination_dir, name), exist_ok=True)
 
for folder in sorted(os.listdir(source_dir)):
    folder_path = os.path.join(source_dir, folder)
    if os.path.isdir(folder_path):
        for file in sorted(os.listdir(folder_path)):
            file_index = int(file[1:3]) - 1  
            target_folder = os.path.join(destination_dir, folder_names[file_index])
            source_file = os.path.join(folder_path, file)
            destination_file = os.path.join(target_folder, file)
            shutil.move(source_file, destination_file)
            print(f"Moved {source_file} to {destination_file}")

# %%
if __name__ == '__main__':
    # Thiết lập thông số HMM
    n_states = 7
    n_mixtures = 3 
    n_features = 13

    # Khởi tạo và huấn luyện HMM
    hmm_train = HMMTraining(n_mixtures=n_mixtures, n_states=n_states, n_features=n_features)
    hmm_train.train_all()

# %%
if __name__ == '__main__':
    n_states = 7
    n_mixtures = 3
    n_features = 13

    hmm_train = HMMTraining(n_mixtures=n_mixtures, n_states=n_states, n_features=n_features)
    hmm_train.load_models()  # Tải các mô hình đã huấn luyện

    # Đường dẫn tới thư mục datasets
    dataset_path = './datasets'

    # Dự đoán và đánh giá toàn bộ dữ liệu
    hmm_train.predict_dataset(dataset_path)
# Out:
# Tải thành công mô hình: A
# Tải thành công mô hình: Ba
# Tải thành công mô hình: Bài
# Tải thành công mô hình: Bảy
# Tải thành công mô hình: Bốn
# Tải thành công mô hình: Chín
# Tải thành công mô hình: Chạy
# Tải thành công mô hình: Chậm
# Tải thành công mô hình: chủ
# Tải thành công mô hình: Cuối
# Tải thành công mô hình: Có
# Tải thành công mô hình: Dừng
# Tải thành công mô hình: E
# Tải thành công mô hình: Giúp
# Tải thành công mô hình: Giảm
# Tải thành công mô hình: Giờ
# Tải thành công mô hình: Hai
# Tải thành công mô hình: Hủy
# Tải thành công mô hình: I
# Tải thành công mô hình: Không
# Tải thành công mô hình: Kế
# Tải thành công mô hình: Lui
# Tải thành công mô hình: Lưu
# Tải thành công mô hình: Lại
# Tải thành công mô hình: Lặp
# Tải thành công mô hình: Một
# Tải thành công mô hình: Mục
# Tải thành công mô hình: Ngày
# Tải thành công mô hình: Ngừng
# Tải thành công mô hình: Nhanh
# Tải thành công mô hình: Nhỏ
# Tải thành công mô hình: Năm
# Tải thành công mô hình: O
# Tải thành công mô hình: Sai
# Tải thành công mô hình: Sáu
# Tải thành công mô hình: Thổ địa
# Tải thành công mô hình: Tiếp
# Tải thành công mô hình: To
# Tải thành công mô hình: Trước
# Tải thành công mô hình: Tám
# Tải thành công mô hình: Tăng
# Tải thành công mô hình: Tươi
# Tải thành công mô hình: Tải
# Tải thành công mô hình: Tới
# Tải thành công mô hình: U
# Tải thành công mô hình: Vào
# Tải thành công mô hình: Về
# Tải thành công mô hình: Xong
# Tải thành công mô hình: Xóa
# Tải thành công mô hình: Đúng
# Tải thành công mô hình: Đầu
# Tải thành công mô hình: Đọc
# Dự đoán lớp: A, Điểm số: -15273.767546573217
# Dự đoán lớp: A, Điểm số: -15120.440918406133
# Dự đoán lớp: A, Điểm số: -16638.177507624685
# Dự đoán lớp: A, Điểm số: -16875.559687221277
# Dự đoán lớp: A, Điểm số: -12532.230781934128
# Dự đoán lớp: A, Điểm số: -13761.4428358462
# Dự đoán lớp: A, Điểm số: -17837.518981291676
# Dự đoán lớp: A, Điểm số: -16015.013300328113
# Dự đoán lớp: O, Điểm số: -12709.549693407464
# Dự đoán lớp: A, Điểm số: -15510.917431399046
# Dự đoán lớp: A, Điểm số: -11195.96064334642
# Dự đoán lớp: A, Điểm số: -15096.070867280816
# Dự đoán lớp: A, Điểm số: -9287.438653214205
# Dự đoán lớp: A, Điểm số: -11872.058227053427
# Dự đoán lớp: A, Điểm số: -21195.34832440907
# Dự đoán lớp: A, Điểm số: -14044.589523268682
# Dự đoán lớp: A, Điểm số: -15896.84363853812
# Dự đoán lớp: A, Điểm số: -14560.147507744368
# Dự đoán lớp: A, Điểm số: -10099.474559210417
# Dự đoán lớp: A, Điểm số: -15139.38781128812
# Dự đoán lớp: Ba, Điểm số: -16160.359096573882
# Dự đoán lớp: Ba, Điểm số: -15005.328647881151
# Dự đoán lớp: Ba, Điểm số: -17043.444577426922
# Dự đoán lớp: Ba, Điểm số: -14502.738142134323
# Dự đoán lớp: Ba, Điểm số: -13523.365594369196
# Dự đoán lớp: Ba, Điểm số: -14271.839648368501
# Dự đoán lớp: Ba, Điểm số: -16640.16611629161
# Dự đoán lớp: Ba, Điểm số: -16331.926576655424
# Dự đoán lớp: Ba, Điểm số: -13667.631903322786
# Dự đoán lớp: Ba, Điểm số: -14904.80380379752
# Dự đoán lớp: Ba, Điểm số: -11994.23065665575
# Dự đoán lớp: Ba, Điểm số: -15271.04247800903
# Dự đoán lớp: Ba, Điểm số: -9258.042566729906
# Dự đoán lớp: Ba, Điểm số: -14063.595132417731
# Dự đoán lớp: Ba, Điểm số: -21723.241632219615
# Dự đoán lớp: Ba, Điểm số: -14437.961486648832
# Dự đoán lớp: Ba, Điểm số: -15513.522151354462
# Dự đoán lớp: Năm, Điểm số: -15324.719916211823
# Dự đoán lớp: Ba, Điểm số: -12725.052076343472
# Dự đoán lớp: Ba, Điểm số: -16181.462565118225
# Dự đoán lớp: Bài, Điểm số: -15607.44554525787
# Dự đoán lớp: Bài, Điểm số: -15582.47231218198
# Dự đoán lớp: Bài, Điểm số: -18310.514848516024
# Dự đoán lớp: Bài, Điểm số: -15705.626582102168
# Dự đoán lớp: Bài, Điểm số: -13194.754787640008
# Dự đoán lớp: Bài, Điểm số: -13151.446630692553
# Dự đoán lớp: Bài, Điểm số: -17534.698815490814
# Dự đoán lớp: Bài, Điểm số: -14860.710653418715
# Dự đoán lớp: Bài, Điểm số: -13443.323656121278
# Dự đoán lớp: Bài, Điểm số: -15028.09106216467
# Dự đoán lớp: Bài, Điểm số: -12902.384800480282
# Dự đoán lớp: Bài, Điểm số: -15348.985011123663
# Dự đoán lớp: Bài, Điểm số: -10531.928623639062
# Dự đoán lớp: Bài, Điểm số: -9626.484587629897
# Dự đoán lớp: Bài, Điểm số: -21252.016259879045
# Dự đoán lớp: Bài, Điểm số: -13341.357822755192
# Dự đoán lớp: Bài, Điểm số: -14948.108449393874
# Dự đoán lớp: Bài, Điểm số: -12946.85626654955
# Dự đoán lớp: Bài, Điểm số: -8201.689718848414
# Dự đoán lớp: Bài, Điểm số: -15525.233952110553
# Dự đoán lớp: Bảy, Điểm số: -14747.947060073318
# Dự đoán lớp: Bảy, Điểm số: -15106.756912607318
# Dự đoán lớp: Bảy, Điểm số: -16615.340897664883
# Dự đoán lớp: Bảy, Điểm số: -15648.912899912979
# Dự đoán lớp: Bảy, Điểm số: -12696.577367590995
# Dự đoán lớp: Bảy, Điểm số: -13214.408158759854
# Dự đoán lớp: Bảy, Điểm số: -18192.503802861
# Dự đoán lớp: Bảy, Điểm số: -16249.190356410085
# Dự đoán lớp: Bảy, Điểm số: -13854.709256984972
# Dự đoán lớp: Bảy, Điểm số: -14089.092237617766
# Dự đoán lớp: Bảy, Điểm số: -11912.420938726624
# Dự đoán lớp: Bảy, Điểm số: -15263.58982617391
# Dự đoán lớp: Bảy, Điểm số: -9010.541983129424
# Dự đoán lớp: Bảy, Điểm số: -10054.043830190127
# Dự đoán lớp: Bảy, Điểm số: -21214.469040908716
# Dự đoán lớp: Bảy, Điểm số: -12534.29703123393
# Dự đoán lớp: Bảy, Điểm số: -15737.070865609641
# Dự đoán lớp: Bảy, Điểm số: -13143.128133945082
# Dự đoán lớp: Bảy, Điểm số: -9976.367879939546
# Dự đoán lớp: Bảy, Điểm số: -16762.670289169553
# Dự đoán lớp: Bốn, Điểm số: -15332.387558906346
# Dự đoán lớp: Bốn, Điểm số: -14607.129106984108
# Dự đoán lớp: Bốn, Điểm số: -16287.481229785393
# Dự đoán lớp: Bốn, Điểm số: -16643.41053247019
# Dự đoán lớp: Bốn, Điểm số: -13132.568448284956
# Dự đoán lớp: Bốn, Điểm số: -12603.945591402644
# Dự đoán lớp: Bốn, Điểm số: -15989.144226165528
# Dự đoán lớp: Bốn, Điểm số: -15920.173088066553
# Dự đoán lớp: Bốn, Điểm số: -12548.40844778224
# Dự đoán lớp: Bốn, Điểm số: -13354.545087740498
# Dự đoán lớp: Bốn, Điểm số: -10905.447267891896
# Dự đoán lớp: Bốn, Điểm số: -14947.594750440248
# Dự đoán lớp: Bốn, Điểm số: -8400.467982940745
# Dự đoán lớp: Bốn, Điểm số: -10072.602701936827
# Dự đoán lớp: Bốn, Điểm số: -22968.17300608578
# Dự đoán lớp: Bốn, Điểm số: -12612.645541115075
# Dự đoán lớp: Bốn, Điểm số: -14975.67020635446
# Dự đoán lớp: Bốn, Điểm số: -13645.3201522288
# Dự đoán lớp: Bốn, Điểm số: -13425.725995620242
# Dự đoán lớp: Bốn, Điểm số: -15534.030462930792
# Dự đoán lớp: Chín, Điểm số: -14544.711458343121
# Dự đoán lớp: Chín, Điểm số: -14140.437376066902
# Dự đoán lớp: Chín, Điểm số: -15762.06166288436
# Dự đoán lớp: Chín, Điểm số: -16002.093870007728
# Dự đoán lớp: Chín, Điểm số: -11916.69996912263
# Dự đoán lớp: Chín, Điểm số: -11823.20315987174
# Dự đoán lớp: Chín, Điểm số: -18864.08028352864
# Dự đoán lớp: Chín, Điểm số: -15936.177605281524
# Dự đoán lớp: Chín, Điểm số: -13200.270811700255
# Dự đoán lớp: Chín, Điểm số: -14654.557057464732
# Dự đoán lớp: Chín, Điểm số: -11408.62623965865
# Dự đoán lớp: Chín, Điểm số: -13755.847948092158
# Dự đoán lớp: Chín, Điểm số: -8070.581895795776
# Dự đoán lớp: Chín, Điểm số: -11586.81211343366
# Dự đoán lớp: Chín, Điểm số: -19161.792041464527
# Dự đoán lớp: Chín, Điểm số: -11752.640679438793
# Dự đoán lớp: Chín, Điểm số: -16896.66862738506
# Dự đoán lớp: Chín, Điểm số: -12868.902766756024
# Dự đoán lớp: Chín, Điểm số: -8437.510337156393
# Dự đoán lớp: Chín, Điểm số: -14636.361757074448
# Dự đoán lớp: Chạy, Điểm số: -14672.827057759447
# Dự đoán lớp: Chạy, Điểm số: -14987.254186058086
# Dự đoán lớp: Chạy, Điểm số: -17414.2702735058
# Dự đoán lớp: Chạy, Điểm số: -15512.276990560382
# Dự đoán lớp: Chạy, Điểm số: -12618.980410720915
# Dự đoán lớp: Chạy, Điểm số: -13729.227549748104
# Dự đoán lớp: Chạy, Điểm số: -15685.20668836957
# Dự đoán lớp: Chạy, Điểm số: -16112.045472194646
# Dự đoán lớp: Chạy, Điểm số: -12991.225840220177
# Dự đoán lớp: Chạy, Điểm số: -14836.179207522438
# Dự đoán lớp: Chạy, Điểm số: -10997.537895113273
# Dự đoán lớp: Chạy, Điểm số: -15320.66437416289
# Dự đoán lớp: Chạy, Điểm số: -8915.342015768521
# Dự đoán lớp: Chạy, Điểm số: -10706.730680939188
# Dự đoán lớp: Chạy, Điểm số: -19210.0954369943
# Dự đoán lớp: Chạy, Điểm số: -13346.365061193199
# Dự đoán lớp: Chạy, Điểm số: -13972.390754820193
# Dự đoán lớp: Chậm, Điểm số: -14801.788870320575
# Dự đoán lớp: Chạy, Điểm số: -9943.837369168055
# Dự đoán lớp: Chạy, Điểm số: -13935.20105117278
# Dự đoán lớp: Chậm, Điểm số: -16003.82178955283
# Dự đoán lớp: Chậm, Điểm số: -14787.218226768291
# Dự đoán lớp: Chậm, Điểm số: -14868.93147645365
# Dự đoán lớp: Chậm, Điểm số: -16620.853922469767
# Dự đoán lớp: Chậm, Điểm số: -12733.426669668404
# Dự đoán lớp: Chậm, Điểm số: -12674.371221061381
# Dự đoán lớp: Chậm, Điểm số: -14856.596353084413
# Dự đoán lớp: Chậm, Điểm số: -14677.765319029964
# Dự đoán lớp: Chậm, Điểm số: -12671.416670608056
# Dự đoán lớp: Chậm, Điểm số: -14262.331351021396
# Dự đoán lớp: Chậm, Điểm số: -11382.540935547955
# Dự đoán lớp: Chậm, Điểm số: -14548.578560186095
# Dự đoán lớp: Chậm, Điểm số: -9287.500653715537
# Dự đoán lớp: Chậm, Điểm số: -11268.55843140828
# Dự đoán lớp: Chậm, Điểm số: -21163.91990480873
# Dự đoán lớp: Chậm, Điểm số: -11881.907385938915
# Dự đoán lớp: Chậm, Điểm số: -15567.23668461848
# Dự đoán lớp: Chậm, Điểm số: -13067.319753503412
# Dự đoán lớp: Chậm, Điểm số: -14209.625329676397
# Dự đoán lớp: Chậm, Điểm số: -15909.914938705422
# Dự đoán lớp: chủ, Điểm số: -14326.409539681606
# Dự đoán lớp: chủ, Điểm số: -14093.376402036334
# Dự đoán lớp: chủ, Điểm số: -14579.778809428586
# Dự đoán lớp: chủ, Điểm số: -14821.996934759241
# Dự đoán lớp: chủ, Điểm số: -11275.857085616575
# Dự đoán lớp: chủ, Điểm số: -11659.836283647175
# Dự đoán lớp: chủ, Điểm số: -17710.91789479559
# Dự đoán lớp: chủ, Điểm số: -15375.05081410943
# Dự đoán lớp: chủ, Điểm số: -7874.914954055528
# Dự đoán lớp: chủ, Điểm số: -16883.012549683586
# Dự đoán lớp: chủ, Điểm số: -16288.55529824821
# Dự đoán lớp: chủ, Điểm số: -13959.942436080426
# Dự đoán lớp: chủ, Điểm số: -11311.09188743613
# Dự đoán lớp: chủ, Điểm số: -9273.145450273083
# Dự đoán lớp: chủ, Điểm số: -15363.640428435994
# Dự đoán lớp: chủ, Điểm số: -12361.232933022893
# Dự đoán lớp: chủ, Điểm số: -26940.594831990955
# Dự đoán lớp: chủ, Điểm số: -9334.022161436873
# Dự đoán lớp: chủ, Điểm số: -14865.601044735835
# Dự đoán lớp: chủ, Điểm số: -15041.968449660277
# Dự đoán lớp: Cuối, Điểm số: -13980.730054866548
# Dự đoán lớp: Cuối, Điểm số: -15852.7699778292
# Dự đoán lớp: Cuối, Điểm số: -16436.42401552078
# Dự đoán lớp: Cuối, Điểm số: -17133.84793220565
# Dự đoán lớp: Cuối, Điểm số: -12378.757921177865
# Dự đoán lớp: Cuối, Điểm số: -14440.3201828123
# Dự đoán lớp: Cuối, Điểm số: -17304.03948680894
# Dự đoán lớp: Cuối, Điểm số: -16116.943973067326
# Dự đoán lớp: Cuối, Điểm số: -12819.436019454177
# Dự đoán lớp: Cuối, Điểm số: -14347.335678225338
# Dự đoán lớp: Cuối, Điểm số: -11286.512215256615
# Dự đoán lớp: Cuối, Điểm số: -15460.57180202325
# Dự đoán lớp: Cuối, Điểm số: -8295.170696793446
# Dự đoán lớp: Cuối, Điểm số: -10982.290788947807
# Dự đoán lớp: Cuối, Điểm số: -17495.383724958832
# Dự đoán lớp: Cuối, Điểm số: -12249.313396636793
# Dự đoán lớp: Cuối, Điểm số: -14094.668263918631
# Dự đoán lớp: Cuối, Điểm số: -12489.55601613531
# Dự đoán lớp: Cuối, Điểm số: -9153.388194185145
# Dự đoán lớp: Cuối, Điểm số: -15687.328864746689
# Dự đoán lớp: Có, Điểm số: -16737.120757717545
# Dự đoán lớp: Có, Điểm số: -14866.969542330378
# Dự đoán lớp: Có, Điểm số: -16928.00168676465
# Dự đoán lớp: Có, Điểm số: -16589.49526980516
# Dự đoán lớp: Có, Điểm số: -13721.44005965998
# Dự đoán lớp: Có, Điểm số: -13834.121224771297
# Dự đoán lớp: Có, Điểm số: -16857.51632638367
# Dự đoán lớp: Có, Điểm số: -16678.273528053847
# Dự đoán lớp: Bốn, Điểm số: -12315.649338644778
# Dự đoán lớp: Có, Điểm số: -15475.976911293657
# Dự đoán lớp: Có, Điểm số: -11269.640567335353
# Dự đoán lớp: Có, Điểm số: -14669.20682836246
# Dự đoán lớp: Có, Điểm số: -9335.222717796449
# Dự đoán lớp: Có, Điểm số: -12377.828119224108
# Dự đoán lớp: Có, Điểm số: -20411.180048948732
# Dự đoán lớp: Có, Điểm số: -14956.404645466695
# Dự đoán lớp: Có, Điểm số: -14557.440839460367
# Dự đoán lớp: Có, Điểm số: -14121.658308234673
# Dự đoán lớp: Có, Điểm số: -11399.758360796646
# Dự đoán lớp: Có, Điểm số: -16187.836530619332
# Dự đoán lớp: Dừng, Điểm số: -14488.670556326491
# Dự đoán lớp: Dừng, Điểm số: -15484.741460921845
# Dự đoán lớp: Dừng, Điểm số: -16603.85966460481
# Dự đoán lớp: Dừng, Điểm số: -16671.153058451873
# Dự đoán lớp: Dừng, Điểm số: -11706.215414849796
# Dự đoán lớp: Dừng, Điểm số: -12535.785516838725
# Dự đoán lớp: Dừng, Điểm số: -16289.213540675179
# Dự đoán lớp: Dừng, Điểm số: -15770.836875105597
# Dự đoán lớp: Dừng, Điểm số: -10903.765554827603
# Dự đoán lớp: Dừng, Điểm số: -13386.025769088425
# Dự đoán lớp: Dừng, Điểm số: -11905.67495888719
# Dự đoán lớp: Dừng, Điểm số: -14339.317653807682
# Dự đoán lớp: Dừng, Điểm số: -8386.04533341664
# Dự đoán lớp: Dừng, Điểm số: -9768.229249099677
# Dự đoán lớp: Dừng, Điểm số: -18144.073860094188
# Dự đoán lớp: Dừng, Điểm số: -12271.300715988022
# Dự đoán lớp: Dừng, Điểm số: -14888.069605406348
# Dự đoán lớp: Dừng, Điểm số: -11698.740449648605
# Dự đoán lớp: Dừng, Điểm số: -10121.31904364005
# Dự đoán lớp: Dừng, Điểm số: -14976.792736893703
# Dự đoán lớp: E, Điểm số: -14794.552916101755
# Dự đoán lớp: E, Điểm số: -15282.137430314966
# Dự đoán lớp: E, Điểm số: -17314.467204449098
# Dự đoán lớp: E, Điểm số: -14798.26683484761
# Dự đoán lớp: E, Điểm số: -12850.915779362402
# Dự đoán lớp: E, Điểm số: -12604.67698919521
# Dự đoán lớp: E, Điểm số: -16013.939532501177
# Dự đoán lớp: E, Điểm số: -16333.83671247301
# Dự đoán lớp: Về, Điểm số: -12507.70977791177
# Dự đoán lớp: E, Điểm số: -14348.757880719868
# Dự đoán lớp: E, Điểm số: -11552.356197897609
# Dự đoán lớp: E, Điểm số: -14931.302709253034
# Dự đoán lớp: E, Điểm số: -7789.948215026224
# Dự đoán lớp: E, Điểm số: -13337.58973551727
# Dự đoán lớp: E, Điểm số: -19757.693557421808
# Dự đoán lớp: E, Điểm số: -13426.180449621781
# Dự đoán lớp: E, Điểm số: -14907.10785552415
# Dự đoán lớp: E, Điểm số: -13217.837543252337
# Dự đoán lớp: E, Điểm số: -8175.175686221254
# Dự đoán lớp: E, Điểm số: -15629.601761629581
# Dự đoán lớp: Giúp, Điểm số: -14453.445256425972
# Dự đoán lớp: Giúp, Điểm số: -13765.272988988494
# Dự đoán lớp: Giúp, Điểm số: -15070.759541057954
# Dự đoán lớp: Giúp, Điểm số: -15597.67203066839
# Dự đoán lớp: Giúp, Điểm số: -11777.05387152048
# Dự đoán lớp: Giúp, Điểm số: -11586.277167551736
# Dự đoán lớp: Giúp, Điểm số: -15113.482544151804
# Dự đoán lớp: Giúp, Điểm số: -14777.386689885763
# Dự đoán lớp: Giúp, Điểm số: -12602.106942503
# Dự đoán lớp: Giúp, Điểm số: -13184.42161512551
# Dự đoán lớp: Giúp, Điểm số: -10015.262875944694
# Dự đoán lớp: Giúp, Điểm số: -13314.080458284583
# Dự đoán lớp: Giúp, Điểm số: -7864.974455241997
# Dự đoán lớp: Giúp, Điểm số: -11052.777282460862
# Dự đoán lớp: Giúp, Điểm số: -17598.329751124234
# Dự đoán lớp: Giúp, Điểm số: -13242.811744578992
# Dự đoán lớp: Giúp, Điểm số: -14990.672226673954
# Dự đoán lớp: Giúp, Điểm số: -10017.692257659648
# Dự đoán lớp: Giúp, Điểm số: -5590.373225827163
# Dự đoán lớp: Giúp, Điểm số: -14911.181780686444
# Dự đoán lớp: Giảm, Điểm số: -16192.889059578627
# Dự đoán lớp: Giảm, Điểm số: -16443.885605269326
# Dự đoán lớp: Giảm, Điểm số: -18709.243994966528
# Dự đoán lớp: Giảm, Điểm số: -17173.8422839091
# Dự đoán lớp: Giảm, Điểm số: -13081.0630324468
# Dự đoán lớp: Giảm, Điểm số: -13804.266997579618
# Dự đoán lớp: Giảm, Điểm số: -16383.722140053955
# Dự đoán lớp: Giảm, Điểm số: -17149.124704204318
# Dự đoán lớp: Giảm, Điểm số: -16190.605841969675
# Dự đoán lớp: Giảm, Điểm số: -13509.106325996034
# Dự đoán lớp: Giảm, Điểm số: -11800.085828576026
# Dự đoán lớp: Giảm, Điểm số: -15977.002753092056
# Dự đoán lớp: Giảm, Điểm số: -8268.90023511715
# Dự đoán lớp: Giảm, Điểm số: -12863.502327119657
# Dự đoán lớp: Giảm, Điểm số: -19441.97394767683
# Dự đoán lớp: Giảm, Điểm số: -13415.578618070987
# Dự đoán lớp: Giảm, Điểm số: -15851.801024976661
# Dự đoán lớp: Giảm, Điểm số: -13747.59028288347
# Dự đoán lớp: Giảm, Điểm số: -8488.892300061394
# Dự đoán lớp: Giảm, Điểm số: -15801.266439101213
# Dự đoán lớp: Giờ, Điểm số: -16221.59350266308
# Dự đoán lớp: Giờ, Điểm số: -16018.179341434477
# Dự đoán lớp: Giờ, Điểm số: -17205.21710814718
# Dự đoán lớp: Giờ, Điểm số: -16929.541507161655
# Dự đoán lớp: Giờ, Điểm số: -13835.756951127176
# Dự đoán lớp: Giờ, Điểm số: -13175.697212338215
# Dự đoán lớp: Giờ, Điểm số: -18813.971632484063
# Dự đoán lớp: Giờ, Điểm số: -15788.525082728396
# Dự đoán lớp: Dừng, Điểm số: -14416.518170134766
# Dự đoán lớp: Giờ, Điểm số: -14616.07189374137
# Dự đoán lớp: Giờ, Điểm số: -11867.58757780611
# Dự đoán lớp: Giờ, Điểm số: -14993.298408477904
# Dự đoán lớp: Giờ, Điểm số: -8833.434110122911
# Dự đoán lớp: Giờ, Điểm số: -8382.339611522939
# Dự đoán lớp: Giờ, Điểm số: -15569.217443388541
# Dự đoán lớp: Giờ, Điểm số: -13781.371426223297
# Dự đoán lớp: Giờ, Điểm số: -14877.493108655133
# Dự đoán lớp: Giờ, Điểm số: -11889.243750549544
# Dự đoán lớp: Giờ, Điểm số: -8304.445699611362
# Dự đoán lớp: Giờ, Điểm số: -15682.205057170635
# Dự đoán lớp: Hai, Điểm số: -15012.008202211646
# Dự đoán lớp: Hai, Điểm số: -15859.393901209065
# Dự đoán lớp: Hai, Điểm số: -17828.719036971885
# Dự đoán lớp: Hai, Điểm số: -14393.28908724594
# Dự đoán lớp: Hai, Điểm số: -14334.22466883779
# Dự đoán lớp: Hai, Điểm số: -13704.621865666159
# Dự đoán lớp: Hai, Điểm số: -16584.320651391714
# Dự đoán lớp: Hai, Điểm số: -15441.067319267819
# Dự đoán lớp: Hai, Điểm số: -14268.51443858852
# Dự đoán lớp: Hai, Điểm số: -13977.660349737038
# Dự đoán lớp: Hai, Điểm số: -11770.327629092153
# Dự đoán lớp: Hai, Điểm số: -16400.633546812962
# Dự đoán lớp: Hai, Điểm số: -8945.121013618558
# Dự đoán lớp: Hai, Điểm số: -11659.267109900355
# Dự đoán lớp: Hai, Điểm số: -21347.265564149642
# Dự đoán lớp: Hai, Điểm số: -14053.669363777499
# Dự đoán lớp: Hai, Điểm số: -15056.450072684727
# Dự đoán lớp: Hai, Điểm số: -14026.731298225615
# Dự đoán lớp: Hai, Điểm số: -9760.93087262474
# Dự đoán lớp: Hai, Điểm số: -15714.893684436849
# Dự đoán lớp: Hủy, Điểm số: -14831.109125038514
# Dự đoán lớp: Hủy, Điểm số: -16400.942587939204
# Dự đoán lớp: Hủy, Điểm số: -16792.02173465051
# Dự đoán lớp: Hủy, Điểm số: -16094.111448632673
# Dự đoán lớp: Hủy, Điểm số: -13057.495819352083
# Dự đoán lớp: Hủy, Điểm số: -12939.784809769313
# Dự đoán lớp: Hủy, Điểm số: -18657.322155486385
# Dự đoán lớp: Hủy, Điểm số: -15786.3759682767
# Dự đoán lớp: Hủy, Điểm số: -13077.832473731947
# Dự đoán lớp: Hủy, Điểm số: -14447.363387263971
# Dự đoán lớp: Hủy, Điểm số: -11804.615074729665
# Dự đoán lớp: Hủy, Điểm số: -14370.70276239334
# Dự đoán lớp: Hủy, Điểm số: -8627.592138118294
# Dự đoán lớp: Hủy, Điểm số: -14802.827954439874
# Dự đoán lớp: Hủy, Điểm số: -17325.050634137977
# Dự đoán lớp: Hủy, Điểm số: -13637.426075259658
# Dự đoán lớp: Hủy, Điểm số: -14376.70633896846
# Dự đoán lớp: Hủy, Điểm số: -15835.397929859671
# Dự đoán lớp: Về, Điểm số: -10828.632208146742
# Dự đoán lớp: Hủy, Điểm số: -15065.113498597948
# Dự đoán lớp: I, Điểm số: -14743.575984105168
# Dự đoán lớp: I, Điểm số: -14183.946392258684
# Dự đoán lớp: I, Điểm số: -16591.522865434843
# Dự đoán lớp: I, Điểm số: -16562.559981965736
# Dự đoán lớp: I, Điểm số: -11997.499804031644
# Dự đoán lớp: I, Điểm số: -11785.953968526865
# Dự đoán lớp: I, Điểm số: -16271.532585771096
# Dự đoán lớp: I, Điểm số: -15144.041985069978
# Dự đoán lớp: I, Điểm số: -13827.244602132212
# Dự đoán lớp: I, Điểm số: -14625.555474315335
# Dự đoán lớp: I, Điểm số: -11432.569726542939
# Dự đoán lớp: I, Điểm số: -14012.634182344209
# Dự đoán lớp: I, Điểm số: -8892.598088648767
# Dự đoán lớp: I, Điểm số: -7698.184351509277
# Dự đoán lớp: I, Điểm số: -20671.560536934812
# Dự đoán lớp: I, Điểm số: -12348.30461869669
# Dự đoán lớp: I, Điểm số: -14304.269590310278
# Dự đoán lớp: I, Điểm số: -13075.101566207819
# Dự đoán lớp: I, Điểm số: -8695.793720816324
# Dự đoán lớp: I, Điểm số: -15543.471188227733
# Dự đoán lớp: Không, Điểm số: -15386.840383203655
# Dự đoán lớp: Không, Điểm số: -15101.76809468137
# Dự đoán lớp: Không, Điểm số: -16888.440082770026
# Dự đoán lớp: Không, Điểm số: -15725.840060523547
# Dự đoán lớp: Không, Điểm số: -12652.412769218992
# Dự đoán lớp: Không, Điểm số: -12391.21204525443
# Dự đoán lớp: Không, Điểm số: -17511.640248541895
# Dự đoán lớp: Không, Điểm số: -15748.180617712287
# Dự đoán lớp: Không, Điểm số: -13318.773613724032
# Dự đoán lớp: Không, Điểm số: -14597.311759146594
# Dự đoán lớp: Không, Điểm số: -10662.859182879929
# Dự đoán lớp: Không, Điểm số: -15445.922801563089
# Dự đoán lớp: Không, Điểm số: -8880.363293108168
# Dự đoán lớp: Không, Điểm số: -11661.556455570473
# Dự đoán lớp: Không, Điểm số: -20522.277193749087
# Dự đoán lớp: Không, Điểm số: -12655.207215748173
# Dự đoán lớp: Không, Điểm số: -15600.616210383443
# Dự đoán lớp: Không, Điểm số: -14462.164221844
# Dự đoán lớp: Không, Điểm số: -10899.464934324315
# Dự đoán lớp: Không, Điểm số: -15115.724182805709
# Dự đoán lớp: Kế, Điểm số: -15074.503207712054
# Dự đoán lớp: Kế, Điểm số: -14976.047068198692
# Dự đoán lớp: Kế, Điểm số: -14730.422263719238
# Dự đoán lớp: Kế, Điểm số: -16991.824852820704
# Dự đoán lớp: Kế, Điểm số: -12855.908080972127
# Dự đoán lớp: Kế, Điểm số: -13371.615392157535
# Dự đoán lớp: Kế, Điểm số: -16698.489117671543
# Dự đoán lớp: Về, Điểm số: -17066.392018155573
# Dự đoán lớp: Kế, Điểm số: -10656.594583017682
# Dự đoán lớp: Kế, Điểm số: -13247.159318610042
# Dự đoán lớp: Kế, Điểm số: -12658.958852596472
# Dự đoán lớp: Kế, Điểm số: -14877.695653502733
# Dự đoán lớp: Kế, Điểm số: -8247.907316929874
# Dự đoán lớp: Kế, Điểm số: -12071.624405417655
# Dự đoán lớp: Kế, Điểm số: -20137.013479520334
# Dự đoán lớp: Kế, Điểm số: -12573.782403824383
# Dự đoán lớp: Kế, Điểm số: -15732.035436275868
# Dự đoán lớp: Kế, Điểm số: -12306.105111180867
# Dự đoán lớp: Kế, Điểm số: -7938.990975453738
# Dự đoán lớp: Kế, Điểm số: -15267.024690255968
# Dự đoán lớp: Lui, Điểm số: -15420.93319893435
# Dự đoán lớp: Lui, Điểm số: -15218.59710608358
# Dự đoán lớp: Lui, Điểm số: -17404.755091975072
# Dự đoán lớp: Lui, Điểm số: -16432.12313208322
# Dự đoán lớp: Lui, Điểm số: -11945.270946283315
# Dự đoán lớp: Lui, Điểm số: -13462.28629763546
# Dự đoán lớp: Lui, Điểm số: -15334.41374414341
# Dự đoán lớp: Lui, Điểm số: -16080.177687362808
# Dự đoán lớp: Lui, Điểm số: -11631.348434964328
# Dự đoán lớp: Lui, Điểm số: -14872.555638815225
# Dự đoán lớp: Lui, Điểm số: -13213.368911923897
# Dự đoán lớp: Lui, Điểm số: -13844.795506569413
# Dự đoán lớp: Lui, Điểm số: -8493.510736191112
# Dự đoán lớp: Lui, Điểm số: -11498.890508269422
# Dự đoán lớp: Lui, Điểm số: -17600.41134580676
# Dự đoán lớp: Lui, Điểm số: -13005.716605574802
# Dự đoán lớp: Lui, Điểm số: -16168.405995729156
# Dự đoán lớp: Lui, Điểm số: -13822.211204856172
# Dự đoán lớp: Lui, Điểm số: -11857.910444772648
# Dự đoán lớp: Lui, Điểm số: -15128.695107134916
# Dự đoán lớp: Lưu, Điểm số: -15456.979590080438
# Dự đoán lớp: Lưu, Điểm số: -15617.169576310222
# Dự đoán lớp: Lưu, Điểm số: -16296.139901323968
# Dự đoán lớp: Lưu, Điểm số: -16960.52530213806
# Dự đoán lớp: Lưu, Điểm số: -13194.743705265853
# Dự đoán lớp: Lưu, Điểm số: -12325.36941905258
# Dự đoán lớp: Lưu, Điểm số: -17829.24231106362
# Dự đoán lớp: Lưu, Điểm số: -15858.229984583439
# Dự đoán lớp: Lưu, Điểm số: -13386.039749802536
# Dự đoán lớp: Lưu, Điểm số: -14065.618693851164
# Dự đoán lớp: Lưu, Điểm số: -11775.61467220218
# Dự đoán lớp: Lưu, Điểm số: -14962.42976074862
# Dự đoán lớp: Lưu, Điểm số: -8233.426670592311
# Dự đoán lớp: Lưu, Điểm số: -9840.923485970361
# Dự đoán lớp: Lưu, Điểm số: -19636.832798297342
# Dự đoán lớp: Lưu, Điểm số: -13217.774289648
# Dự đoán lớp: Lưu, Điểm số: -13342.294235170564
# Dự đoán lớp: Lưu, Điểm số: -13574.020835089219
# Dự đoán lớp: Lưu, Điểm số: -8234.428490533865
# Dự đoán lớp: Lưu, Điểm số: -14901.874629889697
# Dự đoán lớp: Lại, Điểm số: -16789.51916383006
# Dự đoán lớp: Lại, Điểm số: -14820.085944348497
# Dự đoán lớp: Lại, Điểm số: -17809.0156028166
# Dự đoán lớp: Lại, Điểm số: -16511.937501900153
# Dự đoán lớp: Lại, Điểm số: -12655.437890346611
# Dự đoán lớp: Lại, Điểm số: -13506.794772157755
# Dự đoán lớp: Lại, Điểm số: -15950.434101935021
# Dự đoán lớp: Lại, Điểm số: -15191.453873902154
# Dự đoán lớp: Lại, Điểm số: -14893.092059434683
# Dự đoán lớp: Lại, Điểm số: -15576.847071754888
# Dự đoán lớp: Lại, Điểm số: -12211.911409622111
# Dự đoán lớp: Lại, Điểm số: -15236.812135776963
# Dự đoán lớp: Lại, Điểm số: -8642.866304501982
# Dự đoán lớp: Lại, Điểm số: -10282.672152445002
# Dự đoán lớp: Lại, Điểm số: -21824.501588521747
# Dự đoán lớp: Lại, Điểm số: -13432.63322339429
# Dự đoán lớp: Lại, Điểm số: -14557.615051577295
# Dự đoán lớp: Lặp, Điểm số: -13054.823335456826
# Dự đoán lớp: Lại, Điểm số: -13344.669122359399
# Dự đoán lớp: Lại, Điểm số: -16043.532388618807
# Dự đoán lớp: Lặp, Điểm số: -14908.994660124203
# Dự đoán lớp: Lặp, Điểm số: -15419.601636480866
# Dự đoán lớp: Lặp, Điểm số: -16396.808105978354
# Dự đoán lớp: Lặp, Điểm số: -16466.235608905434
# Dự đoán lớp: Lặp, Điểm số: -12026.20339387917
# Dự đoán lớp: Lặp, Điểm số: -12668.12119079401
# Dự đoán lớp: Lặp, Điểm số: -15803.704330108878
# Dự đoán lớp: Lặp, Điểm số: -14991.511690680649
# Dự đoán lớp: Lặp, Điểm số: -13059.404876271528
# Dự đoán lớp: Lặp, Điểm số: -13334.19774886069
# Dự đoán lớp: Lặp, Điểm số: -11218.203595424236
# Dự đoán lớp: Lặp, Điểm số: -13867.180250621383
# Dự đoán lớp: Lặp, Điểm số: -7936.635908892186
# Dự đoán lớp: Lặp, Điểm số: -11768.901282698598
# Dự đoán lớp: Lặp, Điểm số: -21012.754152850284
# Dự đoán lớp: Lặp, Điểm số: -11958.264365816316
# Dự đoán lớp: Lặp, Điểm số: -14320.720388162414
# Dự đoán lớp: Lặp, Điểm số: -13726.326382221849
# Dự đoán lớp: Lặp, Điểm số: -10853.475474705712
# Dự đoán lớp: Lặp, Điểm số: -14684.691578282005
# Dự đoán lớp: Một, Điểm số: -15144.940667938828
# Dự đoán lớp: Một, Điểm số: -14553.165826113805
# Dự đoán lớp: Một, Điểm số: -15838.442270662685
# Dự đoán lớp: Một, Điểm số: -14985.971019410312
# Dự đoán lớp: Một, Điểm số: -12673.853991606748
# Dự đoán lớp: Một, Điểm số: -12905.529866089873
# Dự đoán lớp: Một, Điểm số: -17390.999640509483
# Dự đoán lớp: Một, Điểm số: -15965.47281736379
# Dự đoán lớp: Một, Điểm số: -13176.558985488628
# Dự đoán lớp: Một, Điểm số: -13369.109305281148
# Dự đoán lớp: Một, Điểm số: -10996.297530670168
# Dự đoán lớp: Một, Điểm số: -15360.404374782403
# Dự đoán lớp: Một, Điểm số: -8004.0868052790365
# Dự đoán lớp: Một, Điểm số: -8794.03133868243
# Dự đoán lớp: Mục, Điểm số: -20698.243406536494
# Dự đoán lớp: Một, Điểm số: -12216.458945586579
# Dự đoán lớp: Một, Điểm số: -14485.405569302166
# Dự đoán lớp: Một, Điểm số: -13736.290814632799
# Dự đoán lớp: Một, Điểm số: -10081.263797232456
# Dự đoán lớp: Một, Điểm số: -14992.826860105353
# Dự đoán lớp: Mục, Điểm số: -14806.991668379182
# Dự đoán lớp: Mục, Điểm số: -14311.342052808832
# Dự đoán lớp: Mục, Điểm số: -14258.778166272567
# Dự đoán lớp: Mục, Điểm số: -12231.388705497198
# Dự đoán lớp: Mục, Điểm số: -11531.74819175146
# Dự đoán lớp: Mục, Điểm số: -11765.04753552799
# Dự đoán lớp: Mục, Điểm số: -15810.107776353718
# Dự đoán lớp: Mục, Điểm số: -14916.246897761985
# Dự đoán lớp: Mục, Điểm số: -10463.078349707605
# Dự đoán lớp: Mục, Điểm số: -12327.679012245384
# Dự đoán lớp: Mục, Điểm số: -10725.32882564371
# Dự đoán lớp: Mục, Điểm số: -13691.721961060635
# Dự đoán lớp: Mục, Điểm số: -8195.703869187317
# Dự đoán lớp: Mục, Điểm số: -8668.02564797302
# Dự đoán lớp: Mục, Điểm số: -21761.512534387024
# Dự đoán lớp: Mục, Điểm số: -12261.75085564221
# Dự đoán lớp: Mục, Điểm số: -13915.056857492553
# Dự đoán lớp: Mục, Điểm số: -13332.111463322572
# Dự đoán lớp: Mục, Điểm số: -6315.203949993784
# Dự đoán lớp: Mục, Điểm số: -14537.649731998872
# Dự đoán lớp: Ngày, Điểm số: -15876.576023541784
# Dự đoán lớp: Ngày, Điểm số: -14338.876109932206
# Dự đoán lớp: Ngày, Điểm số: -15169.765797154729
# Dự đoán lớp: Ngày, Điểm số: -15812.041258429781
# Dự đoán lớp: Ngày, Điểm số: -13038.775210747428
# Dự đoán lớp: Ngày, Điểm số: -13867.049102758581
# Dự đoán lớp: Ngày, Điểm số: -16768.366206800532
# Dự đoán lớp: Ngày, Điểm số: -16269.595278305784
# Dự đoán lớp: Ngày, Điểm số: -12364.762168439061
# Dự đoán lớp: Ngày, Điểm số: -15136.594345554884
# Dự đoán lớp: Ngày, Điểm số: -10680.810064142433
# Dự đoán lớp: Ngày, Điểm số: -15240.146156724235
# Dự đoán lớp: Ngày, Điểm số: -8451.078843724485
# Dự đoán lớp: Ngày, Điểm số: -12930.620484990131
# Dự đoán lớp: Ngày, Điểm số: -18645.03583863635
# Dự đoán lớp: Ngày, Điểm số: -13712.214994055244
# Dự đoán lớp: Ngày, Điểm số: -13638.288302973016
# Dự đoán lớp: Năm, Điểm số: -12653.845616054548
# Dự đoán lớp: Ngày, Điểm số: -9598.499693242222
# Dự đoán lớp: Ngày, Điểm số: -16057.890445647388
# Dự đoán lớp: Ngừng, Điểm số: -15215.634733635561
# Dự đoán lớp: Ngừng, Điểm số: -14756.953833926456
# Dự đoán lớp: Ngừng, Điểm số: -15712.089797378794
# Dự đoán lớp: Ngừng, Điểm số: -16510.49949890194
# Dự đoán lớp: Ngừng, Điểm số: -12337.015596743959
# Dự đoán lớp: Ngừng, Điểm số: -13496.927005452826
# Dự đoán lớp: Ngừng, Điểm số: -13944.087111231318
# Dự đoán lớp: Ngừng, Điểm số: -14610.551959934402
# Dự đoán lớp: Ngừng, Điểm số: -10743.349139394883
# Dự đoán lớp: Ngừng, Điểm số: -13830.090440966509
# Dự đoán lớp: Ngừng, Điểm số: -10257.67139184437
# Dự đoán lớp: Ngừng, Điểm số: -14297.989849442003
# Dự đoán lớp: Ngừng, Điểm số: -7354.923252052451
# Dự đoán lớp: Ngừng, Điểm số: -12148.050925653104
# Dự đoán lớp: Ngừng, Điểm số: -17740.734267103824
# Dự đoán lớp: Ngừng, Điểm số: -12565.348891979871
# Dự đoán lớp: Ngừng, Điểm số: -15212.507437580849
# Dự đoán lớp: Ngừng, Điểm số: -11155.046655532373
# Dự đoán lớp: Ngừng, Điểm số: -10487.226408845601
# Dự đoán lớp: Ngừng, Điểm số: -14688.387205905008
# Dự đoán lớp: Nhanh, Điểm số: -15430.449703912971
# Dự đoán lớp: Nhanh, Điểm số: -15904.495592823529
# Dự đoán lớp: Nhanh, Điểm số: -16148.311972231497
# Dự đoán lớp: Nhanh, Điểm số: -15818.298930467905
# Dự đoán lớp: Nhanh, Điểm số: -12370.899252982099
# Dự đoán lớp: Nhanh, Điểm số: -13210.367476780066
# Dự đoán lớp: Nhanh, Điểm số: -14352.235684063455
# Dự đoán lớp: Nhanh, Điểm số: -16669.180465132704
# Dự đoán lớp: Nhanh, Điểm số: -13156.336277981885
# Dự đoán lớp: Nhanh, Điểm số: -15048.443164346365
# Dự đoán lớp: Nhanh, Điểm số: -11495.03511954158
# Dự đoán lớp: Nhanh, Điểm số: -14900.06193532975
# Dự đoán lớp: Nhanh, Điểm số: -8316.691471573371
# Dự đoán lớp: Nhanh, Điểm số: -11016.385541800793
# Dự đoán lớp: Nhanh, Điểm số: -22344.93220742691
# Dự đoán lớp: Nhanh, Điểm số: -11837.918223200095
# Dự đoán lớp: Nhanh, Điểm số: -15802.873406557144
# Dự đoán lớp: Giúp, Điểm số: -12916.356728336892
# Dự đoán lớp: Nhanh, Điểm số: -12423.607669188556
# Dự đoán lớp: Nhanh, Điểm số: -15692.055975060193
# Dự đoán lớp: Nhỏ, Điểm số: -17012.839504723852
# Dự đoán lớp: Nhỏ, Điểm số: -16541.324940244394
# Dự đoán lớp: Nhỏ, Điểm số: -18491.57272560358
# Dự đoán lớp: Nhỏ, Điểm số: -17664.819566747683
# Dự đoán lớp: Nhỏ, Điểm số: -13093.016292420358
# Dự đoán lớp: Nhỏ, Điểm số: -13689.30848008169
# Dự đoán lớp: Nhỏ, Điểm số: -17051.121848522984
# Dự đoán lớp: Nhỏ, Điểm số: -16891.921314521675
# Dự đoán lớp: Đúng, Điểm số: -13593.487211622207
# Dự đoán lớp: Nhỏ, Điểm số: -13984.051908405507
# Dự đoán lớp: Nhỏ, Điểm số: -12573.800778730401
# Dự đoán lớp: Nhỏ, Điểm số: -16263.331077843786
# Dự đoán lớp: Nhỏ, Điểm số: -8926.255796680554
# Dự đoán lớp: Nhỏ, Điểm số: -13984.561820056397
# Dự đoán lớp: Nhỏ, Điểm số: -22158.18066222719
# Dự đoán lớp: Nhỏ, Điểm số: -13125.292745124425
# Dự đoán lớp: Nhỏ, Điểm số: -15389.917466634219
# Dự đoán lớp: Nhỏ, Điểm số: -13744.539359356346
# Dự đoán lớp: Nhỏ, Điểm số: -11557.49233101614
# Dự đoán lớp: Nhỏ, Điểm số: -16535.05750485598
# Dự đoán lớp: Năm, Điểm số: -16030.334623513148
# Dự đoán lớp: Năm, Điểm số: -15180.643915259949
# Dự đoán lớp: Năm, Điểm số: -16566.64642832624
# Dự đoán lớp: Năm, Điểm số: -17079.8397488066
# Dự đoán lớp: Năm, Điểm số: -12933.720558121182
# Dự đoán lớp: Năm, Điểm số: -12818.57735135579
# Dự đoán lớp: Năm, Điểm số: -15606.970210027195
# Dự đoán lớp: Năm, Điểm số: -14958.944141260612
# Dự đoán lớp: Năm, Điểm số: -12967.895282242214
# Dự đoán lớp: Năm, Điểm số: -13913.64159352173
# Dự đoán lớp: Năm, Điểm số: -11194.641752417996
# Dự đoán lớp: Năm, Điểm số: -15224.953070533456
# Dự đoán lớp: Năm, Điểm số: -8336.357034898696
# Dự đoán lớp: Năm, Điểm số: -9879.982999469548
# Dự đoán lớp: Năm, Điểm số: -21004.98993921418
# Dự đoán lớp: Năm, Điểm số: -12608.351123461096
# Dự đoán lớp: Năm, Điểm số: -16331.215771086516
# Dự đoán lớp: Năm, Điểm số: -14341.039376019191
# Dự đoán lớp: Năm, Điểm số: -10979.846082767257
# Dự đoán lớp: Năm, Điểm số: -15101.492195975372
# Dự đoán lớp: O, Điểm số: -15395.97719772288
# Dự đoán lớp: O, Điểm số: -15514.698011245038
# Dự đoán lớp: O, Điểm số: -17101.17933020652
# Dự đoán lớp: O, Điểm số: -17674.47476282853
# Dự đoán lớp: O, Điểm số: -13369.0392947045
# Dự đoán lớp: O, Điểm số: -13802.838354766998
# Dự đoán lớp: O, Điểm số: -16916.502404232808
# Dự đoán lớp: O, Điểm số: -13941.998032149577
# Dự đoán lớp: Một, Điểm số: -13674.864006990809
# Dự đoán lớp: O, Điểm số: -15388.40978993736
# Dự đoán lớp: O, Điểm số: -12225.931635759287
# Dự đoán lớp: O, Điểm số: -14906.365210889702
# Dự đoán lớp: O, Điểm số: -9843.09392936455
# Dự đoán lớp: O, Điểm số: -12470.747717734577
# Dự đoán lớp: O, Điểm số: -19144.193034440083
# Dự đoán lớp: O, Điểm số: -13771.419840524177
# Dự đoán lớp: O, Điểm số: -16543.67450527433
# Dự đoán lớp: O, Điểm số: -13802.69066125849
# Dự đoán lớp: O, Điểm số: -7111.653070778291
# Dự đoán lớp: O, Điểm số: -15998.467725119403
# Dự đoán lớp: Sai, Điểm số: -16361.414934392205
# Dự đoán lớp: Sai, Điểm số: -15765.497284361873
# Dự đoán lớp: Sai, Điểm số: -17299.82469697935
# Dự đoán lớp: Sai, Điểm số: -18408.02526054299
# Dự đoán lớp: Sai, Điểm số: -14012.221260353148
# Dự đoán lớp: Sai, Điểm số: -14162.646841030533
# Dự đoán lớp: Sai, Điểm số: -18793.016931095583
# Dự đoán lớp: Sai, Điểm số: -16451.965828440643
# Dự đoán lớp: Sai, Điểm số: -13995.958368091038
# Dự đoán lớp: Sai, Điểm số: -15684.937746101323
# Dự đoán lớp: Sai, Điểm số: -12601.350200309565
# Dự đoán lớp: Sai, Điểm số: -17147.669527393864
# Dự đoán lớp: Sai, Điểm số: -9161.266076155001
# Dự đoán lớp: Sai, Điểm số: -10380.934273646653
# Dự đoán lớp: Sai, Điểm số: -16677.202769754258
# Dự đoán lớp: Sai, Điểm số: -14057.623490016356
# Dự đoán lớp: Sai, Điểm số: -16237.814424813518
# Dự đoán lớp: Sai, Điểm số: -12861.580513884639
# Dự đoán lớp: Sai, Điểm số: -8391.126731270195
# Dự đoán lớp: Sai, Điểm số: -15767.152515632495
# Dự đoán lớp: Sáu, Điểm số: -15846.643087949597
# Dự đoán lớp: Sáu, Điểm số: -15736.033250893108
# Dự đoán lớp: Sáu, Điểm số: -17136.77391101548
# Dự đoán lớp: Sáu, Điểm số: -16797.331365673665
# Dự đoán lớp: Sáu, Điểm số: -14832.14995444672
# Dự đoán lớp: Sáu, Điểm số: -13977.15324462155
# Dự đoán lớp: Sáu, Điểm số: -18236.5798558621
# Dự đoán lớp: Sáu, Điểm số: -16483.449897210896
# Dự đoán lớp: Sáu, Điểm số: -14062.9870670284
# Dự đoán lớp: Sáu, Điểm số: -14478.489665583307
# Dự đoán lớp: Sáu, Điểm số: -12583.896838004288
# Dự đoán lớp: Sáu, Điểm số: -15630.81972752783
# Dự đoán lớp: Sáu, Điểm số: -9190.089055702856
# Dự đoán lớp: Sáu, Điểm số: -8708.585270267911
# Dự đoán lớp: Sáu, Điểm số: -19879.438366887636
# Dự đoán lớp: Sáu, Điểm số: -14113.608758234363
# Dự đoán lớp: Sáu, Điểm số: -15875.057846890402
# Dự đoán lớp: Sáu, Điểm số: -15551.371454771417
# Dự đoán lớp: Sáu, Điểm số: -9218.061405724453
# Dự đoán lớp: Sáu, Điểm số: -16315.448771841844
# Dự đoán lớp: Thổ địa, Điểm số: -15453.642798646008
# Dự đoán lớp: Thổ địa, Điểm số: -16425.13408851764
# Dự đoán lớp: Thổ địa, Điểm số: -18021.76090827992
# Dự đoán lớp: Thổ địa, Điểm số: -15749.2352822123
# Dự đoán lớp: Thổ địa, Điểm số: -15601.664512763313
# Dự đoán lớp: Thổ địa, Điểm số: -14354.375594154866
# Dự đoán lớp: Thổ địa, Điểm số: -15965.558933447192
# Dự đoán lớp: Thổ địa, Điểm số: -16319.140030753882
# Dự đoán lớp: Thổ địa, Điểm số: -17527.677318374514
# Dự đoán lớp: Thổ địa, Điểm số: -22031.99704774253
# Dự đoán lớp: Thổ địa, Điểm số: -19388.964209596717
# Dự đoán lớp: Thổ địa, Điểm số: -17351.790258706176
# Dự đoán lớp: Thổ địa, Điểm số: -17348.821534370192
# Dự đoán lớp: Thổ địa, Điểm số: -12504.543354664478
# Dự đoán lớp: Thổ địa, Điểm số: -18106.35305046631
# Dự đoán lớp: Thổ địa, Điểm số: -13330.327998873616
# Dự đoán lớp: Thổ địa, Điểm số: -27679.078261828916
# Dự đoán lớp: Thổ địa, Điểm số: -9862.729542174853
# Dự đoán lớp: Thổ địa, Điểm số: -8236.30260706326
# Dự đoán lớp: Thổ địa, Điểm số: -16941.487516744146
# Dự đoán lớp: Tiếp, Điểm số: -13807.322889494424
# Dự đoán lớp: Tiếp, Điểm số: -14745.654742820132
# Dự đoán lớp: Tiếp, Điểm số: -14430.843259246776
# Dự đoán lớp: Tiếp, Điểm số: -15611.269468264252
# Dự đoán lớp: Tiếp, Điểm số: -11849.606753064443
# Dự đoán lớp: Tiếp, Điểm số: -12408.426504440506
# Dự đoán lớp: Tiếp, Điểm số: -16718.024155116946
# Dự đoán lớp: Tiếp, Điểm số: -14171.75857815247
# Dự đoán lớp: Tiếp, Điểm số: -11111.461952492908
# Dự đoán lớp: Tiếp, Điểm số: -14198.877144390857
# Dự đoán lớp: Tiếp, Điểm số: -11634.144704053566
# Dự đoán lớp: Tiếp, Điểm số: -13686.685735486297
# Dự đoán lớp: Tiếp, Điểm số: -7768.29716506576
# Dự đoán lớp: Tiếp, Điểm số: -11919.367836497979
# Dự đoán lớp: Tiếp, Điểm số: -15223.600095238797
# Dự đoán lớp: Tiếp, Điểm số: -10941.142193041325
# Dự đoán lớp: Tiếp, Điểm số: -15186.036984795792
# Dự đoán lớp: Tiếp, Điểm số: -12600.54323798142
# Dự đoán lớp: Tiếp, Điểm số: -6675.493420348583
# Dự đoán lớp: Tiếp, Điểm số: -15135.810130988366
# Dự đoán lớp: To, Điểm số: -15903.212158166887
# Dự đoán lớp: To, Điểm số: -16236.047638756674
# Dự đoán lớp: To, Điểm số: -17165.34007701424
# Dự đoán lớp: To, Điểm số: -17741.383214185906
# Dự đoán lớp: To, Điểm số: -13050.060571609429
# Dự đoán lớp: To, Điểm số: -13533.69394117478
# Dự đoán lớp: To, Điểm số: -16181.124578854053
# Dự đoán lớp: To, Điểm số: -17202.227148192058
# Dự đoán lớp: To, Điểm số: -12001.45153159947
# Dự đoán lớp: To, Điểm số: -13592.372403589163
# Dự đoán lớp: To, Điểm số: -12115.759388642016
# Dự đoán lớp: To, Điểm số: -15845.1653095698
# Dự đoán lớp: To, Điểm số: -9605.703463680115
# Dự đoán lớp: To, Điểm số: -16657.993222380228
# Dự đoán lớp: To, Điểm số: -21054.52148079178
# Dự đoán lớp: To, Điểm số: -13232.73523860207
# Dự đoán lớp: To, Điểm số: -15302.142603470913
# Dự đoán lớp: To, Điểm số: -14451.343282558695
# Dự đoán lớp: To, Điểm số: -9636.709231833
# Dự đoán lớp: To, Điểm số: -15979.263367027777
# Dự đoán lớp: Trước, Điểm số: -13495.940411231464
# Dự đoán lớp: Trước, Điểm số: -14347.744739636068
# Dự đoán lớp: Trước, Điểm số: -16120.216785324503
# Dự đoán lớp: Trước, Điểm số: -15381.468079214246
# Dự đoán lớp: Trước, Điểm số: -12153.95165769286
# Dự đoán lớp: Trước, Điểm số: -12117.355041872752
# Dự đoán lớp: Trước, Điểm số: -16643.082514403082
# Dự đoán lớp: Vào, Điểm số: -15655.474638595351
# Dự đoán lớp: Trước, Điểm số: -11419.466929189739
# Dự đoán lớp: Trước, Điểm số: -13457.273659454784
# Dự đoán lớp: Trước, Điểm số: -12356.068385822542
# Dự đoán lớp: Trước, Điểm số: -13368.555072111625
# Dự đoán lớp: Trước, Điểm số: -8266.439122812415
# Dự đoán lớp: Trước, Điểm số: -13777.860594495234
# Dự đoán lớp: Trước, Điểm số: -19938.063123408214
# Dự đoán lớp: Trước, Điểm số: -11487.106677873262
# Dự đoán lớp: Trước, Điểm số: -14982.834934656774
# Dự đoán lớp: Trước, Điểm số: -12067.732039748376
# Dự đoán lớp: Trước, Điểm số: -9673.455473449934
# Dự đoán lớp: Trước, Điểm số: -14203.890254893728
# Dự đoán lớp: Tám, Điểm số: -15696.065750273989
# Dự đoán lớp: Tám, Điểm số: -14914.20557994185
# Dự đoán lớp: Tám, Điểm số: -18291.67902781859
# Dự đoán lớp: Tám, Điểm số: -15993.620743522799
# Dự đoán lớp: Tám, Điểm số: -13106.036003004083
# Dự đoán lớp: Tám, Điểm số: -13588.584837267295
# Dự đoán lớp: Tám, Điểm số: -17192.98768987032
# Dự đoán lớp: Tám, Điểm số: -15896.702478794432
# Dự đoán lớp: Tám, Điểm số: -13787.891640166272
# Dự đoán lớp: Tám, Điểm số: -14353.657456881736
# Dự đoán lớp: Tám, Điểm số: -11128.532608151761
# Dự đoán lớp: Tám, Điểm số: -14677.962456358007
# Dự đoán lớp: Có, Điểm số: -8818.46349909303
# Dự đoán lớp: Tám, Điểm số: -10669.375692180594
# Dự đoán lớp: Tám, Điểm số: -20377.65573872803
# Dự đoán lớp: Tám, Điểm số: -13545.441780206673
# Dự đoán lớp: Tám, Điểm số: -15106.026954995123
# Dự đoán lớp: Tám, Điểm số: -14827.24372187731
# Dự đoán lớp: Tám, Điểm số: -14726.576420186693
# Dự đoán lớp: Tám, Điểm số: -15883.300737289337
# Dự đoán lớp: Tăng, Điểm số: -17334.54338233303
# Dự đoán lớp: Tăng, Điểm số: -15273.908959163633
# Dự đoán lớp: Tăng, Điểm số: -16989.20478195292
# Dự đoán lớp: Tăng, Điểm số: -17438.087173920536
# Dự đoán lớp: Tăng, Điểm số: -11951.734482228016
# Dự đoán lớp: Tăng, Điểm số: -13740.21966366955
# Dự đoán lớp: Tăng, Điểm số: -16852.429321436764
# Dự đoán lớp: Tăng, Điểm số: -15000.112113729869
# Dự đoán lớp: Tăng, Điểm số: -11165.492036445803
# Dự đoán lớp: Tăng, Điểm số: -14157.73648333319
# Dự đoán lớp: Tăng, Điểm số: -11356.576246321572
# Dự đoán lớp: Tăng, Điểm số: -15201.761267124306
# Dự đoán lớp: Tăng, Điểm số: -8457.968237418016
# Dự đoán lớp: Tăng, Điểm số: -14492.211592100533
# Dự đoán lớp: Tăng, Điểm số: -18705.63418368188
# Dự đoán lớp: Tăng, Điểm số: -14021.58438735823
# Dự đoán lớp: Tăng, Điểm số: -13907.611549570423
# Dự đoán lớp: Tăng, Điểm số: -14156.383284634641
# Dự đoán lớp: Tăng, Điểm số: -12896.375009067566
# Dự đoán lớp: Tăng, Điểm số: -14948.404471198939
# Dự đoán lớp: Tươi, Điểm số: -16168.912062225088
# Dự đoán lớp: Tươi, Điểm số: -14812.073368620486
# Dự đoán lớp: Tươi, Điểm số: -15618.63234312062
# Dự đoán lớp: Tươi, Điểm số: -16350.578990703865
# Dự đoán lớp: Tươi, Điểm số: -12780.305056038806
# Dự đoán lớp: Tươi, Điểm số: -11637.914637519065
# Dự đoán lớp: Tươi, Điểm số: -16323.213503866631
# Dự đoán lớp: Tươi, Điểm số: -15806.262053008822
# Dự đoán lớp: Tươi, Điểm số: -13699.659837020396
# Dự đoán lớp: Tươi, Điểm số: -15141.35977963965
# Dự đoán lớp: Tươi, Điểm số: -11682.12985771072
# Dự đoán lớp: Tươi, Điểm số: -15313.426277540811
# Dự đoán lớp: Tươi, Điểm số: -8484.026203025076
# Dự đoán lớp: Tươi, Điểm số: -8647.287461237825
# Dự đoán lớp: Tươi, Điểm số: -19610.3319669138
# Dự đoán lớp: Tươi, Điểm số: -14286.904815562577
# Dự đoán lớp: Tươi, Điểm số: -15160.674493408136
# Dự đoán lớp: Tươi, Điểm số: -12177.700440355939
# Dự đoán lớp: Tươi, Điểm số: -13228.427883684233
# Dự đoán lớp: Tươi, Điểm số: -14555.227667250378
# Dự đoán lớp: Tải, Điểm số: -16856.25730738126
# Dự đoán lớp: Tải, Điểm số: -16225.89359505146
# Dự đoán lớp: Tải, Điểm số: -15748.91470367893
# Dự đoán lớp: Tải, Điểm số: -15232.997691023802
# Dự đoán lớp: Tải, Điểm số: -12917.517216049131
# Dự đoán lớp: Tải, Điểm số: -13626.536870458505
# Dự đoán lớp: Tải, Điểm số: -14002.70310936686
# Dự đoán lớp: Tải, Điểm số: -15596.255305972862
# Dự đoán lớp: Tải, Điểm số: -12259.963548364365
# Dự đoán lớp: Tải, Điểm số: -13942.573022256294
# Dự đoán lớp: Tải, Điểm số: -11280.684021944246
# Dự đoán lớp: Tải, Điểm số: -15493.49658410406
# Dự đoán lớp: Tải, Điểm số: -9458.129932195232
# Dự đoán lớp: Tải, Điểm số: -10626.222936063197
# Dự đoán lớp: Tải, Điểm số: -17901.13066780979
# Dự đoán lớp: Tải, Điểm số: -12358.800904846083
# Dự đoán lớp: Tải, Điểm số: -13778.71520690321
# Dự đoán lớp: Tải, Điểm số: -12760.72568123145
# Dự đoán lớp: Tải, Điểm số: -9453.278567180208
# Dự đoán lớp: Tải, Điểm số: -15712.33477721166
# Dự đoán lớp: Tới, Điểm số: -15228.176625731308
# Dự đoán lớp: Tới, Điểm số: -16198.300991734546
# Dự đoán lớp: Tới, Điểm số: -16692.634936124872
# Dự đoán lớp: Tới, Điểm số: -15983.855909411099
# Dự đoán lớp: Tới, Điểm số: -13130.634259104108
# Dự đoán lớp: Tới, Điểm số: -13093.355904259352
# Dự đoán lớp: Tới, Điểm số: -15123.804751076474
# Dự đoán lớp: Tới, Điểm số: -16115.347035197505
# Dự đoán lớp: Lui, Điểm số: -12251.345561973705
# Dự đoán lớp: Tới, Điểm số: -14365.370120752801
# Dự đoán lớp: Tới, Điểm số: -12404.971214218556
# Dự đoán lớp: Tới, Điểm số: -15400.623869688798
# Dự đoán lớp: Tới, Điểm số: -8918.221576529435
# Dự đoán lớp: Tới, Điểm số: -11812.085074386823
# Dự đoán lớp: Tới, Điểm số: -19058.289485020927
# Dự đoán lớp: Tới, Điểm số: -13231.800918897245
# Dự đoán lớp: Tới, Điểm số: -14221.970035832914
# Dự đoán lớp: Tới, Điểm số: -13305.760247693044
# Dự đoán lớp: Tới, Điểm số: -12370.831422574458
# Dự đoán lớp: Tới, Điểm số: -15269.067274133406
# Dự đoán lớp: U, Điểm số: -14784.807338099854
# Dự đoán lớp: U, Điểm số: -14622.316491761025
# Dự đoán lớp: U, Điểm số: -16347.525416943203
# Dự đoán lớp: U, Điểm số: -14781.435302836891
# Dự đoán lớp: U, Điểm số: -12794.429223194591
# Dự đoán lớp: U, Điểm số: -11428.935915969028
# Dự đoán lớp: U, Điểm số: -15054.458466106369
# Dự đoán lớp: U, Điểm số: -14167.685638697309
# Dự đoán lớp: U, Điểm số: -13014.51398576321
# Dự đoán lớp: U, Điểm số: -15175.270460906082
# Dự đoán lớp: U, Điểm số: -10687.21537116566
# Dự đoán lớp: U, Điểm số: -14298.91778090646
# Dự đoán lớp: U, Điểm số: -7268.831135338317
# Dự đoán lớp: U, Điểm số: -12770.484012152561
# Dự đoán lớp: U, Điểm số: -16384.09149166432
# Dự đoán lớp: U, Điểm số: -13127.83533562467
# Dự đoán lớp: U, Điểm số: -14012.048282140126
# Dự đoán lớp: U, Điểm số: -11031.534803328457
# Dự đoán lớp: U, Điểm số: -9813.734960261714
# Dự đoán lớp: U, Điểm số: -15310.990550843906
# Dự đoán lớp: Vào, Điểm số: -17994.27808871352
# Dự đoán lớp: Vào, Điểm số: -15879.217757411701
# Dự đoán lớp: Vào, Điểm số: -16143.080024110131
# Dự đoán lớp: Vào, Điểm số: -16086.6776265419
# Dự đoán lớp: Vào, Điểm số: -12843.063763951195
# Dự đoán lớp: Vào, Điểm số: -13559.566019979387
# Dự đoán lớp: Vào, Điểm số: -13753.096060953932
# Dự đoán lớp: Vào, Điểm số: -15621.904299236385
# Dự đoán lớp: Vào, Điểm số: -11524.187935738288
# Dự đoán lớp: Vào, Điểm số: -13381.500541401776
# Dự đoán lớp: Vào, Điểm số: -10973.416835428161
# Dự đoán lớp: Vào, Điểm số: -15318.922055378283
# Dự đoán lớp: Vào, Điểm số: -8695.571281788087
# Dự đoán lớp: Vào, Điểm số: -14598.264691777398
# Dự đoán lớp: Vào, Điểm số: -15614.33503769129
# Dự đoán lớp: Vào, Điểm số: -14353.724096953058
# Dự đoán lớp: Vào, Điểm số: -14877.125771234038
# Dự đoán lớp: Vào, Điểm số: -12881.505121562644
# Dự đoán lớp: Vào, Điểm số: -12219.355998809007
# Dự đoán lớp: Vào, Điểm số: -15866.07362035517
# Dự đoán lớp: Về, Điểm số: -16660.071895921796
# Dự đoán lớp: Về, Điểm số: -15774.646586357794
# Dự đoán lớp: Về, Điểm số: -15998.608939828664
# Dự đoán lớp: Về, Điểm số: -15280.04250586305
# Dự đoán lớp: Về, Điểm số: -11630.14234137559
# Dự đoán lớp: Về, Điểm số: -12359.829980797278
# Dự đoán lớp: Về, Điểm số: -13831.48077541996
# Dự đoán lớp: Về, Điểm số: -17749.925631244987
# Dự đoán lớp: Về, Điểm số: -13382.750253864051
# Dự đoán lớp: Về, Điểm số: -14482.49840790958
# Dự đoán lớp: Về, Điểm số: -10818.407788212824
# Dự đoán lớp: Về, Điểm số: -15270.837141116242
# Dự đoán lớp: Về, Điểm số: -8332.244083855981
# Dự đoán lớp: Về, Điểm số: -10241.844780178819
# Dự đoán lớp: Về, Điểm số: -17242.51111213632
# Dự đoán lớp: Về, Điểm số: -12839.711928895778
# Dự đoán lớp: Về, Điểm số: -13870.22551333463
# Dự đoán lớp: Về, Điểm số: -11970.542124887317
# Dự đoán lớp: Về, Điểm số: -9177.084311996048
# Dự đoán lớp: Về, Điểm số: -15288.831739888312
# Dự đoán lớp: Xong, Điểm số: -15916.913480810304
# Dự đoán lớp: Xong, Điểm số: -14246.156357890106
# Dự đoán lớp: Xong, Điểm số: -17048.328260294948
# Dự đoán lớp: Xong, Điểm số: -15637.776812158318
# Dự đoán lớp: Xong, Điểm số: -14103.090001208988
# Dự đoán lớp: Xong, Điểm số: -13999.35788635483
# Dự đoán lớp: Xong, Điểm số: -15898.277954625022
# Dự đoán lớp: Xong, Điểm số: -16116.01160173842
# Dự đoán lớp: Xong, Điểm số: -14180.195743460437
# Dự đoán lớp: Xong, Điểm số: -15098.403917448595
# Dự đoán lớp: Xong, Điểm số: -10979.051442013164
# Dự đoán lớp: Xong, Điểm số: -15599.451236510884
# Dự đoán lớp: Xong, Điểm số: -8728.283122745679
# Dự đoán lớp: Xong, Điểm số: -12868.466227445893
# Dự đoán lớp: Xong, Điểm số: -20260.901153473827
# Dự đoán lớp: Xong, Điểm số: -13734.054564510592
# Dự đoán lớp: Xong, Điểm số: -15551.155082070645
# Dự đoán lớp: Xong, Điểm số: -13624.601710751022
# Dự đoán lớp: Xong, Điểm số: -13594.47130333193
# Dự đoán lớp: Xong, Điểm số: -15719.531358930022
# Dự đoán lớp: Xóa, Điểm số: -17431.058057012495
# Dự đoán lớp: Xóa, Điểm số: -17082.257520924286
# Dự đoán lớp: Xóa, Điểm số: -16582.735507081292
# Dự đoán lớp: Xóa, Điểm số: -17231.33103944224
# Dự đoán lớp: Xóa, Điểm số: -14378.659136459892
# Dự đoán lớp: Xóa, Điểm số: -14079.38050129676
# Dự đoán lớp: Xóa, Điểm số: -17527.42747470291
# Dự đoán lớp: Xóa, Điểm số: -17011.75924455903
# Dự đoán lớp: Xóa, Điểm số: -15551.001723597525
# Dự đoán lớp: Xóa, Điểm số: -15252.672242867699
# Dự đoán lớp: Xóa, Điểm số: -10917.468004710321
# Dự đoán lớp: Xóa, Điểm số: -16538.87510277553
# Dự đoán lớp: Xóa, Điểm số: -10113.357904000804
# Dự đoán lớp: Xóa, Điểm số: -14338.492739556017
# Dự đoán lớp: Xóa, Điểm số: -18676.547948132666
# Dự đoán lớp: Xóa, Điểm số: -13861.482213511514
# Dự đoán lớp: Xóa, Điểm số: -15798.511715739682
# Dự đoán lớp: Xóa, Điểm số: -12845.421388934583
# Dự đoán lớp: Xóa, Điểm số: -11034.978544795937
# Dự đoán lớp: Xóa, Điểm số: -15707.136255850544
# Dự đoán lớp: Đúng, Điểm số: -14932.96459525419
# Dự đoán lớp: Đúng, Điểm số: -15307.285215090606
# Dự đoán lớp: Đúng, Điểm số: -16278.070951346286
# Dự đoán lớp: Đúng, Điểm số: -15802.493142721745
# Dự đoán lớp: Đúng, Điểm số: -12974.12410218036
# Dự đoán lớp: Đúng, Điểm số: -12937.651932709561
# Dự đoán lớp: Đúng, Điểm số: -17211.457801918543
# Dự đoán lớp: Đúng, Điểm số: -14904.30431740148
# Dự đoán lớp: Đúng, Điểm số: -14879.777240879233
# Dự đoán lớp: Đúng, Điểm số: -14764.747406809496
# Dự đoán lớp: Đúng, Điểm số: -10392.783941598114
# Dự đoán lớp: Đúng, Điểm số: -13687.297646457891
# Dự đoán lớp: Đúng, Điểm số: -8443.506727427835
# Dự đoán lớp: Đúng, Điểm số: -11371.819402035244
# Dự đoán lớp: Đúng, Điểm số: -18952.186746614567
# Dự đoán lớp: Đúng, Điểm số: -12353.47168714095
# Dự đoán lớp: Đúng, Điểm số: -12834.419706631516
# Dự đoán lớp: Đúng, Điểm số: -12530.05305978876
# Dự đoán lớp: Đúng, Điểm số: -8814.040792327332
# Dự đoán lớp: Đúng, Điểm số: -14777.924244417798
# Dự đoán lớp: Đầu, Điểm số: -17271.428888213566
# Dự đoán lớp: Đầu, Điểm số: -15463.679737446897
# Dự đoán lớp: Đầu, Điểm số: -17229.5565350593
# Dự đoán lớp: Đầu, Điểm số: -16526.702552306084
# Dự đoán lớp: Đầu, Điểm số: -12197.555314736497
# Dự đoán lớp: Đầu, Điểm số: -12625.324786181396
# Dự đoán lớp: Đầu, Điểm số: -14740.657282101265
# Dự đoán lớp: Đầu, Điểm số: -16176.05587731067
# Dự đoán lớp: Đầu, Điểm số: -11674.707953994048
# Dự đoán lớp: Đầu, Điểm số: -14511.764594139875
# Dự đoán lớp: Đầu, Điểm số: -11304.24812370422
# Dự đoán lớp: Đầu, Điểm số: -14620.505795422829
# Dự đoán lớp: Đầu, Điểm số: -8367.989417519524
# Dự đoán lớp: Đầu, Điểm số: -13229.619296319304
# Dự đoán lớp: Đầu, Điểm số: -16917.933336842972
# Dự đoán lớp: Đầu, Điểm số: -12556.542927846767
# Dự đoán lớp: Đầu, Điểm số: -15226.210439416389
# Dự đoán lớp: Đầu, Điểm số: -12745.02682019621
# Dự đoán lớp: Đầu, Điểm số: -10359.623197570303
# Dự đoán lớp: Đầu, Điểm số: -15277.123038068847
# Dự đoán lớp: Đọc, Điểm số: -14949.813733134757
# Dự đoán lớp: Đọc, Điểm số: -14885.791230198907
# Dự đoán lớp: Đọc, Điểm số: -15646.665887999985
# Dự đoán lớp: Đọc, Điểm số: -16113.893926632554
# Dự đoán lớp: Đọc, Điểm số: -11971.490344579594
# Dự đoán lớp: Đọc, Điểm số: -13488.511807387833
# Dự đoán lớp: Đọc, Điểm số: -16688.48101489534
# Dự đoán lớp: Đọc, Điểm số: -14857.667583325348
# Dự đoán lớp: Đọc, Điểm số: -12292.459168648817
# Dự đoán lớp: Đọc, Điểm số: -14051.532799790304
# Dự đoán lớp: Đọc, Điểm số: -12428.358607163298
# Dự đoán lớp: Đọc, Điểm số: -15065.00945343529
# Dự đoán lớp: Đọc, Điểm số: -7595.156528303948
# Dự đoán lớp: Đọc, Điểm số: -11876.655587548343
# Dự đoán lớp: Đọc, Điểm số: -17090.78242848123
# Dự đoán lớp: Đọc, Điểm số: -12074.465019184754
# Dự đoán lớp: Đọc, Điểm số: -13274.382755619194
# Dự đoán lớp: Đọc, Điểm số: -13014.936500640244
# Dự đoán lớp: Đọc, Điểm số: -7878.161853752216
# Dự đoán lớp: Đọc, Điểm số: -14964.849146825873
# Accuracy trên tập dữ liệu test: 98.37%
